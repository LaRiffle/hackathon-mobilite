# %%
import pandas as pd

df = pd.read_csv('melun.csv', sep=";")

# %%
points = {}
for index, row in df.iterrows():
    points[';'.join([
        row['D'].replace(',', '.'), 
        row['E'].replace(',', '.')]
    )] = row['G']

# %%
df
# Out:
#          A         B         C                D                 E       F  \
# 0      638  23/05/17  27/11/18  674144,56750500  6827095,32006000   74732
# 1      639  23/05/17  27/11/18  674144,56750500  6827095,32006000   74277
# 2      640  23/05/17  27/11/18  674144,56750500  6827095,32006000   74278
# 3      641  23/05/17  27/11/18  674144,56750500  6827095,32006000   74280
# 4      642  23/05/17  27/11/18  674144,56750500  6827095,32006000   74281
# 5      643  23/05/17  27/11/18  674144,56750500  6827095,32006000   74285
# 6      644  23/05/17  27/11/18  674144,56750500  6827095,32006000   74289
# 7      645  23/05/17  27/11/18  674144,56750500  6827095,32006000   74290
# 8      646  23/05/17  27/11/18  674144,56750500  6827095,32006000   74291
# 9      647  23/05/17  27/11/18  674144,56750500  6827095,32006000   74292
# 10     648  23/05/17  27/11/18  674144,56750500  6827095,32006000   74296
# 11     649  23/05/17  27/11/18  674144,56750500  6827095,32006000   74297
# ...

# %%
points
# Out:
# {'673823,57250700': 'Consultation kinésithérapie',
#  '673919,88908500': 'Consultation kinésithérapie',
#  '674087,73323200': 'Consultation kinésithérapie',
#  '674144,56750500': 'Gastro entérologie',
#  '674145,73092600': 'Consultation kinésithérapie',
#  '674189,73028700': 'Consultation kinésithérapie',
#  '674253,27359800': 'Consultation kinésithérapie',
#  '674382,40980600': 'Consultation kinésithérapie',
#  '674410,17129800': 'Consultation kinésithérapie',
#  '674522,96774000': 'Consultation kinésithérapie',
#  '674592,17263300': 'Résidence Autonomie Yvonne de Gaulle',
#  '674603,33230400': 'Consultation kinésithérapie',
#  '674619,43429900': 'AIDE A DOMICILE MANDATAIRE',
#  '674627,30872400': 'Consultation kinésithérapie',
#  '674655,98863100': 'Consultation kinésithérapie',
#  '674657,47218600': 'Residence Autonomie Blanche de Castille',
#  '674770,01964500': 'Consultation kinésithérapie',
#  '674848,13113700': 'Consultation kinésithérapie',
# ...
